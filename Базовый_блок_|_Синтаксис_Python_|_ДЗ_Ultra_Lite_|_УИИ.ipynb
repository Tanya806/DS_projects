# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanya806/DS_projects/blob/main/%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%8B%D0%B9_%D0%B1%D0%BB%D0%BE%D0%BA_%7C_%D0%A1%D0%B8%D0%BD%D1%82%D0%B0%D0%BA%D1%81%D0%B8%D1%81_Python_%7C_%D0%94%D0%97_Ultra_Lite_%7C_%D0%A3%D0%98%D0%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Создайте набор переменных, которые будут хранить анкетные данные пользователя. Укажите для каждой строчки вашего кода комментарий, который будет отражать смысл производимых действий.

# %% [markdown]
# В зависимости от введенных данных, ответ может быть таким:

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Для этого:
# - создайте переменную с именем **name** и сохраните в ней своё имя;

# %%
# Ваше решение

# %% [markdown]
# - создайте переменную с именем **age** и сохраните в ней свой возраст;

# %%
# Ваше решение

# %% [markdown]
# - создайте переменную с именем **city** и сохраните в ней название населенного пункта, в котором проживаете;

# %%
# Ваше решение

# %% [markdown]
# - используя последовательно три вызова функции `print()`, выведите на экран информацию в следующем виде:
#
#         Привет, меня зовут {name}
#         Мне {age} лет
#         Я живу в {city}
#
#     *Вместо {**name**}, {**age**}, {**city**} должны быть значения созданных вами переменных*.

# %%
# Ваше решение

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Создайте систему общения с пользователем.
#
# P.S. Не забывайте про комментарии!
#
#
# ---
#
# В зависимости от введенных данных ваш результат может быть таким:![img2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Для этого:
#
# - с помощью вызова функции `input()` задайте вопрос "Привет, как тебя зовут?". Введенную пользователем информацию сохраните в переменной с именем **user_name**;

# %%
# Ваше решение

# %% [markdown]
# - с помощью вызова функции `input()` выведите на экран вопрос: "Привет, {**user_name**}, а сколько тебе лет?" (Вместо {**user_name**} должно быть имя, заданное пользователем на предыдущем шаге). Введенный результат сохраните в переменную с именем **user_age**;

# %%
# Ваше решение

# %% [markdown]
# - с помощью вызова функции ```print()``` выведите на экран следующую информацию:
#
#         Создан новый пользователь. Имя: {**user_name**}, возраст: {**user_age**}
#     *Вместо {user_name}, {user_age} должны быть значения созданных вами переменных*.

# %%
# Ваше решение

# %% [markdown]
# ### Задача 3

# %% [markdown]
# На компьютере установлены логин и пароль. Создайте систему проверки данных пользователя.
#
# ---
# В зависимости от введенных данных ваш результат может быть таким:
#
# ![image.png](data:image/png;base64,...)

# %%
# Переменные для авторизации пользователя
login_autorization = '123'
password_autorization = 'qwe'

# %% [markdown]
# Для этого:
#
# *   с помощью вызова функции `input()` попросите пользователя ввести логин и пароль от компьютера. Введенную пользователем информацию сохраните в переменные с именами **login** и **password**

# %%
# Ваше решение

# %% [markdown]
# *   с помощью условного оператора if...else проверьте введенные пользователем логин и пароль. Если логин и пароль введены верно, выведите сообщение "Авторизация прошла успешно."

# %%
# Ваше решение

# %% [markdown]
# * если одна из переменных введена неверно, выведите сообщение: "Неверные данные для авторизации. Проверьте логин и пароль."

# %%
# Ваше решение

# %% [markdown]
# ### Задача 4

# %% [markdown]
# Дан размер файла в килобайтах. Найти количество полных мегабайт, которые занимает данный файл.
#
# * *Подсказка*: 1Mb = 1024kb
# ---
#
# Ваш результат может быть таким:
#
# ![ans1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Для этого:
#
# *   создайте переменную **kb** и сохраните в нее значение **10260** (в этой переменной будет храниться размер файла в килобайтах);

# %%
# Ваше решение

# %% [markdown]
# * с помощью оператора целочисленного деления **//** найдите количество полных мегабайт и остаток в килобайтах с помощью оператора нахождения остатка от деления **%**

# %%
# Ваше решение

# %% [markdown]
# ### Задача 5

# %% [markdown]
# Решите следующую задачу: необходимо проверить возраст посетителей кинотеатра и пропустить только тех зрителей, которые соответствуют возрастной категории фильма.
#
# ---
#
# В зависимости от введенных данных, ваше решение может выглядеть так:
# ![img5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Для этого:
# * создайте перемнную **age_limit** и сохраните в нее значение **16** (в этой переменной будет возрастное ограничение фильма);

# %%
# Ваше решение

# %% [markdown]
# * с помощью функции `input()` попросите пользователя ввести свой возраст и сохраните введенную информацию в переменную **user_age**;

# %%
# Ваше решение

# %% [markdown]
# * с помощью функции `int()` преобразуйте введенную пользователем информацию к типу **int** и сохраните результат в переменной с тем же именем (**user_age**);

# %%
# Ваше решение

# %% [markdown]
# * с помощью условного оператора `if...else` проверьте введенный пользователем возраст:
#
#  - если возраст пользователя меньше возарстного ограничения (**age_limit**), то выведите на экран фразу "К сожалению, Вам еще рано смотреть такие фильмы".
#  - если возраст посетителя больше или равен возрастному ограничению (**age_limit**), то выведите фразу "Проходите. Приятного просмотра!!!"

# %%
# Ваше решение
